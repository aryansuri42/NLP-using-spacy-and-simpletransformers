# %%
# !pip install simpletransformers
# !pip install spacy

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-07-19 05:09:03.654434: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 05:09:05.078247: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-19 05:09:08.189242: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
train_data = [
    {
        "context": """CHANGES
PER COUPON CHARGE INR 3000 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 3000 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00001",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 72 HOURS?",
                "answers": [
                    {
                        "text": "NO CHARGE",
                        "answer_start": 139,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 3000 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 3000 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00002",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 02 HOURS?",
                "answers": [
                    {
                        "text": "3000",
                        "answer_start": 292,
                    }
                ],
            }
       ]
},
{
        "context": """CANCELLATIONS
PER COUPON CHARGE INR 3500 FOR CANCEL.
NOTE
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CANCELLATION FEE APPLIES AS BELOW
WHEN CANCELLATION  ARE MADE BEFORE 72 HOURS OF
DEPARTURE A CHANGE FEE OF INR 2500 PER COUPON
WILL APPLY CANCELLATION MADE WITHIN 72 HOURS UNTILL
02 HOURS BEFORE SCHEDULED DEPARTURE OF
THE FLIGHT AGAINST A CHANGE FEE OF INR 3500 PER""",
        "qas": [
            {
                "id": "00003",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 72 HOURS?",
                "answers": [
                    {
                        "text": "2500",
                        "answer_start": 212,
                    }
                ],
            }
        ],
    },
{
        "context": """CANCELLATIONS
PER COUPON CHARGE INR 3500 FOR CANCEL.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CANCELLATION FEE APPLIES AS BELOW
WHEN CANCELLATION  ARE MADE BEFORE 72 HOURS OF
DEPARTURE A CHANGE FEE OF INR 2500 PER COUPON
WILL APPLY CANCELLATION MADE WITHIN 72 HOURS UNTILL
02 HOURS BEFORE SCHEDULED DEPARTURE OF
THE FLIGHT AGAINST A CHANGE FEE OF INR 3500 PER""",
        "qas": [
            {
                "id": "00004",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 02 HOURS?",
                "answers": [
                    {
                        "text": "3500",
                        "answer_start": 360,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 2750 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOWN
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 3250 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00005",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "2750",
                        "answer_start": 19,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 2750 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 3250 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00006",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "3250",
                        "answer_start": 169,
                    }
                ],
            }
        ],
    },
{
        "context": """CANCELLATIONS
CHARGE INR 3250 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIE
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 3750 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00007",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "3250",
                        "answer_start": 25,
                    }
                ],
            }
        ],
    },
{
        "context": """CANCELLATIONS
CHARGE INR 3250 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIES
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 3750 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00008",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "3750",
                        "answer_start": 206,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 2750 BEFORE 24 HOURS FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOWN
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 3250 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00009",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "2750",
                        "answer_start": 19,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 5000 REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOWN
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 8100 WITHIN 24 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00010",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "5000",
                        "answer_start": 19,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 5000 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 6000 WITHIN 32 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00011",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "6000",
                        "answer_start": 169,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 5000 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 6000 WITHIN 48 HOURS AND BEFORE 24
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00012",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "6000",
                        "answer_start": 169,
                    }
                ],
            }
        ],
    },
{
        "context": """CHANGES
CHARGE INR 5000 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 6000 WITHIN 48 HOURS AND BEFORE 24
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00013",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "5000",
                        "answer_start": 19,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 3000 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 32 HOURS OF
DEPARTURE WITHIN 32 AND UNTIL 03 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 3000 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00014",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 32 HOURS?",
                "answers": [
                    {
                        "text": "NO CHARGE",
                        "answer_start": 139,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 3400 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 48 HOURS OF
DEPARTURE WITHIN 48 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 3400 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00015",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "NO CHARGE",
                        "answer_start": 139,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 6500 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 6500 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00016",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 72 HOURS?",
                "answers": [
                    {
                        "text": "NO CHARGE",
                        "answer_start": 139,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 8400 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 8400 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00017",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 02 HOURS?",
                "answers": [
                    {
                        "text": "8400",
                        "answer_start": 293,
                    }
                ],
            }
       ]
},
    {
        "context": """CHANGES
PER COUPON CHARGE INR 5000 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 01 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 5000 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00018",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 01 HOURS?",
                "answers": [
                    {
                        "text": "5000",
                        "answer_start": 293,
                    }
                ],
            }
       ]
},
    {
        "context": """CHANGES
PER COUPON CHARGE INR 7400 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 45 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 7400 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00019",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 45 HOURS?",
                "answers": [
                    {
                        "text": "7400",
                        "answer_start": 293,
                    }
                ],
            }
       ]
},
    {
        "context": """CHANGES
PER COUPON CHARGE INR 7842 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 12 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 7842 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00020",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 12 HOURS?",
                "answers": [
                    {
                        "text": "7842",
                        "answer_start": 293,
                    }
                ],
            }
       ]
},
    {
        "context": """CHANGES
PER COUPON CHARGE INR 5420 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 12 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 5420 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00021",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 12 HOURS?",
                "answers": [
                    {
                        "text": "5420",
                        "answer_start": 293,
                    }
                ],
            }
       ]
},
    {
        "context": """CHANGES
PER COUPON CHARGE INR 8000 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF
DEPARTURE WITHIN 72 AND UNTIL 12 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 8000 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00022",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 12 HOURS?",
                "answers": [
                    {
                        "text": "8000",
                        "answer_start": 293,
                    }
                ],
            }
       ]
}
]
train_data
# Out:
# [{'context': 'CHANGES\nPER COUPON CHARGE INR 3000 FOR REISSUE/REVALIDATION.\nNOTE -\nTEXT BELOW NOT VALIDATED FOR AUTOPRICING.\nCHANGES FEE APPLIES AS BELOW\nNO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF\nDEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE\nSCHEDULED DEPARTURE OF THE FLIGHT AGAINST A\nCHANGE FEE OF INR 3000 PER COUPON OR BASIC FARE\nWHICH EVER IS LOWER.',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'CHANGE PRICE BEFORE 72 HOURS?',
#     'answers': [{'text': 'NO CHARGE', 'answer_start': 139}]}]},
#  {'context': 'CHANGES\nPER COUPON CHARGE INR 3000 FOR REISSUE/REVALIDATION.\nNOTE -\nTEXT BELOW NOT VALIDATED FOR AUTOPRICING.\nCHANGES FEE APPLIES AS BELOW\nNO CHARGE FOR CHANGES MADE BEFORE 72 HOURS OF\nDEPARTURE WITHIN 72 AND UNTIL 02 HOURS BEFORE\nSCHEDULED DEPARTURE OF THE FLIGHT AGAINST A\nCHANGE FEE OF INR 3000 PER COUPON OR BASIC FARE\nWHICH EVER IS LOWER.',
#   'qas': [{'id': '00002',
#     'is_impossible': False,
# ...

# %%
test_data = [
    {
        "context": """FOR ALL CHANGES 24 HOURS BEFORE DEPARTURE OF A FLIGHT A CHARGE OF 2750 INR MUST BE COLLECTED FOR CHANGE OF RESERVATION. THIS APPLIES PER SECTOR/ROUTE FOR DATE/FLIGHT CHANGE.""",
        "qas": [
            {
                "id": "00001",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "2750",
                        "answer_start": 66,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
    ANY TIME
      CHANGES PERMITTED FOR REISSUE/REVALIDATION.
         NOTE -
          CHARGE INR 500 PER CHANGE. EXCLUSIVE OF GST
          NO CHANGES PERMITTED WITHIN 2 HR OF DEPARTURE""",
        "qas": [
            {
                "id": "00002",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "500",
                        "answer_start": 108,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
    ANY TIME
      CHARGE CAD 100.00 FOR REISSUE/REVALIDATION.
      WAIVED FOR DEATH OF PASSENGER OR FAMILY MEMBER.
         NOTE -
          FOR ALL CHANGES WITHIN 96 HOURS BEFORE DEPARTURE
          OF A FLIGHT A CHARGE OF 110 CAD MUST BE COLLECTED
          FOR CHANGE OF RESERVATION.""",
        "qas": [
            {
                "id": "00003",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 96 HOURS?",
                "answers": [
                    {
                        "text": "100.00",
                        "answer_start": 145,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
    ANY TIME
      CHARGE CAD 300.00 FOR REISSUE/REVALIDATION.
      WAIVED FOR DEATH OF PASSENGER OR FAMILY MEMBER.
         NOTE -
          FOR ALL CHANGES WITHIN 96 HOURS BEFORE DEPARTURE
          OF A FLIGHT A CHARGE OF 330 CAD MUST BE COLLECTED
          FOR CHANGE OF RESERVATION.""",
        "qas": [
            {
                "id": "00004",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 96 HOURS?",
                "answers": [
                    {
                        "text": "300.00",
                        "answer_start": 145,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
CHARGE INR 2000 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 1500 WITHIN 48 HOURS AND BEFORE 24
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00005",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "2000",
                        "answer_start": 19,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
CHARGE INR 2000 FOR REISSUE.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3.
APPLICABLE GST RATE TO BE COLLECTED AND SHOW
SEPARATELY UNDER TAX CODE K3.
CHARGE INR 1500 WITHIN 48 HOURS AND BEFORE 24
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00006",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 24 HOURS?",
                "answers": [
                    {
                        "text": "1500",
                        "answer_start": 169,
                    }
                ],
            }
        ],
    },
    {
         "context": """CANCELLATIONS
CHARGE INR 3250 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIES
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 3750 WITHIN 48 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00007",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "3250",
                        "answer_start": 25,
                    }
                ],
            }
        ],
    },
    {
        "context": """CHANGES
PER COUPON CHARGE INR 8400 FOR REISSUE/REVALIDATION.
NOTE -
TEXT BELOW NOT VALIDATED FOR AUTOPRICING.
CHANGES FEE APPLIES AS BELOW
NO CHARGE FOR CHANGES MADE BEFORE 48 HOURS OF
DEPARTURE WITHIN 48 AND UNTIL 02 HOURS BEFORE
SCHEDULED DEPARTURE OF THE FLIGHT AGAINST A
CHANGE FEE OF INR 8400 PER COUPON OR BASIC FARE
WHICH EVER IS LOWER.""",
        "qas": [
            {
                "id": "00008",
                "is_impossible": False,
                "question": "CHANGE PRICE BEFORE 72 HOURS?",
                "answers": [
                    {
                        "text": "NO CHARGE",
                        "answer_start": 139,
                    }
                ],
            }
        ],
    },
    {
         "context": """CANCELLATIONS
CHARGE INR 4650 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIES
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 5640 WITHIN 48 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00009",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "4650",
                        "answer_start": 25,
                    }
                ],
            },{

                "id": "000032",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "5640",
                        "answer_start": 206,
                    }
                ]
            }
        ],
    },
    {
         "context": """CANCELLATIONS
CHARGE INR 3200 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIES
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 3300 WITHIN 48 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00010",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 2 HOURS?",
                "answers": [
                    {
                        "text": "3300",
                        "answer_start": 206,
                    }
                ],
            }
        ],
    },
    {
         "context": """CANCELLATIONS
CHARGE INR 3500 FOR CANCEL/REFUND.
NOTE -
ABOVE CHARGES ARE EXCLUSIVE OF GST K3 AND APPLIES
PER FARE COMPONENT.
APPLICABLE GST RATE TO BE COLLECTED AND
ADDED TO THE PENALTY AMOUNT.
CHARGE INR 3600 WITHIN 48 HOURS AND BEFORE 2
HOURS OF DEPARTURE OF FLIGHT.""",
        "qas": [
            {
                "id": "00011",
                "is_impossible": False,
                "question": "CANCELLATION PRICE BEFORE 48 HOURS?",
                "answers": [
                    {
                        "text": "3500",
                        "answer_start": 25,
                    }
                ],
            }
        ],
    }
]

test_data
# Out:
# [{'context': 'FOR ALL CHANGES 24 HOURS BEFORE DEPARTURE OF A FLIGHT A CHARGE OF 2750 INR MUST BE COLLECTED FOR CHANGE OF RESERVATION. THIS APPLIES PER SECTOR/ROUTE FOR DATE/FLIGHT CHANGE.',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'CHANGE PRICE BEFORE 24 HOURS?',
#     'answers': [{'text': '2750', 'answer_start': 66}]}]},
#  {'context': 'CHANGES\n    ANY TIME\n      CHANGES PERMITTED FOR REISSUE/REVALIDATION.\n         NOTE -\n          CHARGE INR 500 PER CHANGE. EXCLUSIVE OF GST\n          NO CHANGES PERMITTED WITHIN 2 HR OF DEPARTURE',
#   'qas': [{'id': '00002',
#     'is_impossible': False,
#     'question': 'CHANGE PRICE BEFORE 2 HOURS?',
#     'answers': [{'text': '500', 'answer_start': 108}]}]},
# ...

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
model_type="bert"
model_name= "bert-base-cased"
if model_type == "bert":
    model_name = "bert-base-cased"

elif model_type == "roberta":
    model_name = "roberta-base"

elif model_type == "distilbert":
    model_name = "distilbert-base-cased"

elif model_type == "distilroberta":
    model_type = "roberta"
    model_name = "distilroberta-base"

elif model_type == "electra-base":
    model_type = "electra"
    model_name = "google/electra-base-discriminator"

elif model_type == "electra-small":
    model_type = "electra"
    model_name = "google/electra-small-discriminator"

elif model_type == "xlnet":
    model_name = "xlnet-base-cased"

# %%
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 256,
    "num_train_epochs": 10,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %%
model = QuestionAnsweringModel(
    model_type,model_name, args=train_args
)
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !rm -rf outputs
key = "34a082d80e2e7194f25a46856cadb2658673fc00"

# %%
model.train_model(train_data, eval_data=test_data)
# Out:
# ...
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# wandb: Currently logged in as: aryansuri23 (spiderman). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/content/wandb/run-20230719_051015-o9cow2f5</code>
# Syncing run <strong><a href='https://wandb.ai/spiderman/Question%20Answer%20Application/runs/o9cow2f5' target="_blank">bert-base-cased</a></strong> to <a href='https://wandb.ai/spiderman/Question%20Answer%20Application' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/spiderman/Question%20Answer%20Application' target="_blank">https://wandb.ai/spiderman/Question%20Answer%20Application</a>
#  View run at <a href='https://wandb.ai/spiderman/Question%20Answer%20Application/runs/o9cow2f5' target="_blank">https://wandb.ai/spiderman/Question%20Answer%20Application/runs/o9cow2f5</a>
# ...

# %%
result, texts = model.eval_model(test_data)
# Out:
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_lg")
sys.path.append('/content/drive/MyDrive/Minirules/Project')
import DataCleaning
hrs_list = []
price_list = []
sort_price = []
sort_hrs = []

nlp_object = DataCleaning.FileCleaning("/content/drive/MyDrive/Minirules/YYZCOK-RULE.txt")
rules = nlp_object.changes_split()[0]
for token in nlp(rules):
  if token.pos_=="NUM" and token.ent_type_=="TIME" and token.is_alpha == False:
    hrs = int(token.text)
    if hrs not in hrs_list:
      hrs_list.append(int(token.text))

for i in hrs_list:
  to_predict = [
      {
          "context": str(rules),
          "qas": [
              {
                  "question": f"CHANGE PRICE BEFORE {hrs} HOURS?",
                  "id": "0",
              }
          ],
      }
  ]
  answers, probabilities = model.predict(to_predict)
  answers = answers[-1]['answer']
  for res in answers:
    content = nlp(res)
    for token in range(0, len(content)):
      if content[token].pos_=="NUM" and content[token].ent_type_!="TIME" and content[token].is_alpha==False :
        price = float(content[token].text)
        if price not in price_list and price not in hrs_list:
          price_list.append(price)
      elif content[token].text == "NO" and (content[token+1].text=="CHARGES" or content[token+1].text=="CHARGE"):
        price = 0
        if price not in price_list:
          price_list.append(price)
  for token in nlp(rules):
    if token.pos_=="NUM" and token.ent_type_!="TIME" and token.is_alpha==False and float(token.text) not in price_list and int(token.text) not in hrs_list:
      price = float(token.text)
      if price not in price_list and price not in hrs_list:
          price_list.append(price)
left_index = len(hrs_list) - len(price_list)
sort_price = price_list.sort()
if sort_price==None:
  sort_price = price_list
sort_hrs = hrs_list.sort(reverse = True)
if sort_hrs==None:
  sort_hrs = hrs_list
if sort_price[0]==0:
  sort_price[0]="NO CHARGE"
if left_index > 0:
  for i in range(0,left_index):
    sort_price.append("NO CHANGE PERMITTED")
elif left_index < 0:
  for i in range(0,abs(left_index)):
    sort_hrs.append(0)

if sort_hrs[-1]!=0:
  sort_hrs.append(0)
  sort_price.append("NO CHANGE PERMITTED")
price = dict(zip(sort_hrs, sort_price))
print(price)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# {96: 300.0, 0: 330.0}

# %%
hrs_list = []
price_list = []
sort_price = []
sort_hrs = []
nlp_object = DataCleaning.FileCleaning("/content/drive/MyDrive/Minirules/DELBOM-AI-INR.txt")
rules = nlp_object.cancellation_split()[0]
for token in nlp(rules):
  if token.pos_=="NUM" and token.ent_type_=="TIME" and token.is_alpha == False:
    hrs = int(token.text)
    if hrs not in hrs_list:
      hrs_list.append(int(token.text))

for i in hrs_list:
  to_predict = [
      {
          "context": str(rules),
          "qas": [
              {
                  "question": f"CANCELLATION PRICE BEFORE {hrs} HOURS?",
                  "id": "0",
              }
          ],
      }
  ]
  answers, probabilities = model.predict(to_predict)
  answers = answers[-1]['answer']
  for res in answers:
    content = nlp(res)
    for token in range(0, len(content)):
      if content[token].pos_=="NUM" and content[token].ent_type_!="TIME" and content[token].is_alpha==False :
        price = float(content[token].text)
        if price not in price_list and price not in hrs_list:
          price_list.append(price)
      elif content[token].text == "NO" and (content[token+1].text=="CHARGES" or content[token+1].text=="CHARGE"):
        price = 0
        if price not in price_list:
          price_list.append(price)
  for token in nlp(rules):
    if token.pos_=="NUM" and token.ent_type_!="TIME" and token.is_alpha==False and float(token.text) not in price_list and int(token.text) not in hrs_list:
      price = float(token.text)
      if price not in price_list and price not in hrs_list:
          price_list.append(price)



left_index = len(hrs_list) - len(price_list)
sort_price = price_list.sort()

if sort_price==None:
  sort_price = price_list
sort_hrs = hrs_list.sort(reverse = True)
if sort_hrs==None:
  sort_hrs = hrs_list
if len(sort_price) == 0 and len(sort_hrs) == 0:
  print("TICKET IS NON REFUNDABLE")
if len(sort_price) != 0 and sort_price[0]==0:
  sort_price[0]="NO REFUND"
if left_index > 0:
  for i in range(0,left_index):
    sort_price.append("NO REFUND PERMITTED")
elif left_index < 0:
  for i in range(0,abs(left_index)):
    sort_hrs.append(0)
if len(sort_hrs) != 0 and sort_hrs[-1]!=0:
  sort_hrs.append(0)
  sort_price.append("NO REFUND PERMITTED")
price = dict(zip(sort_hrs, sort_price))
if price!={}:
  print(price)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# {72: 2500.0, 2: 3500.0, 0: 'NO REFUND PERMITTED'}
